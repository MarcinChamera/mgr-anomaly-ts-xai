# %%
import tsai.all
import datetime
import pandas as pd
import torch
import numpy as np
import wandb
from fastai.callback.wandb import WandbCallback
from fastai.callback.tracker import EarlyStoppingCallback, SaveModelCallback
import time
import math

# %% [markdown]
# The author of the architecture (https://github.com/Wensi-Tang/OS-CNN) writes:
#
#
# "OS-CNN achieves SOTA on
#
# UCR and UEA archives and some private datasets.
#
#
# ### with just the default hyperpermeter setting! no need to search!
#
# Just have a try!!!"

# %%
# %run ../../shared_functions.py
# %run ../../my_shared_functions.py

# %%
DIR_INPUT = '../../../fraud-detection-handbook/simulated-data-transformed/data/'

BEGIN_DATE = "2018-06-11"
END_DATE = "2018-09-14"

print("Load  files")
# %time transactions_df=read_from_files(DIR_INPUT, BEGIN_DATE, END_DATE)
print("{0} transactions loaded, containing {1} fraudulent transactions".format(len(transactions_df),transactions_df.TX_FRAUD.sum()))

output_feature="TX_FRAUD"

input_features=['TX_AMOUNT','TX_DURING_WEEKEND', 'TX_DURING_NIGHT', 'CUSTOMER_ID_NB_TX_1DAY_WINDOW',
       'CUSTOMER_ID_AVG_AMOUNT_1DAY_WINDOW', 'CUSTOMER_ID_NB_TX_7DAY_WINDOW',
       'CUSTOMER_ID_AVG_AMOUNT_7DAY_WINDOW', 'CUSTOMER_ID_NB_TX_30DAY_WINDOW',
       'CUSTOMER_ID_AVG_AMOUNT_30DAY_WINDOW', 'TERMINAL_ID_NB_TX_1DAY_WINDOW',
       'TERMINAL_ID_RISK_1DAY_WINDOW', 'TERMINAL_ID_NB_TX_7DAY_WINDOW',
       'TERMINAL_ID_RISK_7DAY_WINDOW', 'TERMINAL_ID_NB_TX_30DAY_WINDOW',
       'TERMINAL_ID_RISK_30DAY_WINDOW']
# Out:
# Load  files
# CPU times: total: 438 ms
# Wall time: 443 ms
# 919767 transactions loaded, containing 8195 fraudulent transactions

# %% [markdown]
# #### Default

# %%
BEGIN_DATE = "2018-08-08"
start_date_training = datetime.datetime.strptime(BEGIN_DATE, "%Y-%m-%d")
delta_train=7
delta_delay=7
delta_test=7

delta_valid = delta_test

(train_df, valid_df)=get_train_test_set(transactions_df,start_date_training,
                                       delta_train=delta_train,delta_delay=delta_delay,delta_test=delta_test)

SEQ_LEN = 5

# %%
SEED = 42

if torch.cuda.is_available():
    DEVICE = "cuda" 
else:
    DEVICE = "cpu"
print("Selected device is",DEVICE)

seed_everything(SEED)
# Out:
# Selected device is cuda

# %%
(train_df, valid_df)=scaleData(train_df, valid_df,input_features)
x_train, y_train = prepare_sequenced_X_y(train_df, SEQ_LEN, input_features, output_feature)
x_valid, y_valid = prepare_sequenced_X_y(valid_df, SEQ_LEN, input_features, output_feature)
X, y, splits = tsai.all.combine_split_data([x_train.numpy(), x_valid.numpy()], [y_train.numpy(), y_valid.numpy()])

# %% [markdown]
# ##### Fit 1 cycle

# %%
config = dict(
    dataset_id = 'fraud-detection-handbook-transformed',
    validation = 'train test split',
    seed = SEED,
    begin_date = BEGIN_DATE,
    delta_train = delta_train,
    delta_delay = delta_delay,
    delta_test = delta_test,
    batch_size=64,
    num_workers=0,
    few_shot=False,
    layers=[8*128, 5 * 128 * 256 + 2 * 256  *128],
    early_stopping=True,
    early_stopping_patience=2,
    max_epochs=100,
    scale=True,
    criterion='bce',
    one_cycle_policy=True
)
wandb.init(project="mgr-anomaly-tsxai-project", config=config, tags=['omniscalecnn', 'tsai', 'imbalance-not-considered'])
config = wandb.config
# Out:
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Currently logged in as: chamera (mgr-anomaly-tsxai). Use `wandb login --relogin` to force relogin
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.01691666666592937, max=1.0)…
# wandb version 0.13.9 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>d:\repos\mgr-anomaly-ts-xai\tsai\tsai-sweeps-models_testing\wandb\run-20230124_175901-2x8pwu2e</code>
# Syncing run <strong><a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/2x8pwu2e" target="_blank">vibrant-paper-576</a></strong> to <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>

# %%
dsets = tsai.all.TSDatasets(X, y, splits=splits, inplace=True)
dls = tsai.all.TSDataLoaders.from_dsets(dsets.train, dsets.valid, bs=config.batch_size, num_workers=config.num_workers, drop_last=False, device=DEVICE)
model = tsai.all.OmniScaleCNN(
    c_in=dls.vars, 
    c_out=dls.c,
    seq_len=SEQ_LEN,
    layers=config.layers,
    few_shot=config.few_shot
    )

# %%
criterion = tsai.all.BCEWithLogitsLossFlat()
learn = tsai.all.ts_learner(
    dls,
    model,
    loss_func=criterion,
    opt_func=tsai.all.Adam,
    device=DEVICE,
    metrics=[],
    model_dir='OmniScaleCNN',
    cbs=[
        WandbCallback(
            log='all',
            log_model=True,
            seed=config.seed),
        EarlyStoppingCallback(
            patience=config.early_stopping_patience
        ),
        SaveModelCallback(
            fname='omniscalecnn_fit_one_cycle'
        )])

# %%
lr = learn.lr_find().valley
wandb.config.update({"lr": lr})
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>

# %%
start_time=time.time()
learn.fit_one_cycle(config.max_epochs, lr)
training_execution_time=time.time()-start_time
# Out:
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.027559</td>
#       <td>0.023904</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.019348</td>
#       <td>0.023911</td>
#       <td>00:26</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.017357</td>
#       <td>0.022224</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.020946</td>
#       <td>0.022789</td>
#       <td>00:27</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.023904</td>
#       <td>0.020860</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.016793</td>
#       <td>0.019740</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.017054</td>
#       <td>0.022019</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.023277</td>
#       <td>0.020519</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>
# Better model found at epoch 0 with valid_loss value: 0.023904016241431236.
# Better model found at epoch 2 with valid_loss value: 0.022223547101020813.
# Better model found at epoch 4 with valid_loss value: 0.02085997350513935.
# Better model found at epoch 5 with valid_loss value: 0.01974044367671013.
# No improvement since epoch 5: early stopping

# %%
start_time=time.time()
valid_predictions_logits = get_predictions_sequential(learn.model.cuda(), dls.valid)
prediction_execution_time=time.time()-start_time
predictions_df = valid_df
predictions_df['predictions'] = torch.nn.Sigmoid()(torch.FloatTensor(valid_predictions_logits)).numpy()
    
performance_df = performance_assessment_f1_included(predictions_df, top_k_list=[100])
performance_df
# Out:
#    AUC ROC  Average precision  F1 score  Card Precision@100
# 0    0.894              0.655     0.652               0.297

# %%
wandb.log({'Training execution time': training_execution_time})
wandb.log({'Prediction execution time': prediction_execution_time})
wandb.log({'AUC ROC': performance_df.loc[0,'AUC ROC']})
wandb.log({'Average precision': performance_df.loc[0,'Average precision']})
wandb.log({'F1 score': performance_df.loc[0,'F1 score']})
wandb.log({'Card Precision@100': performance_df.loc[0,'Card Precision@100']})
wandb.finish()
# Out:
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>▁</td></tr><tr><td>Average precision</td><td>▁</td></tr><tr><td>Card Precision@100</td><td>▁</td></tr><tr><td>F1 score</td><td>▁</td></tr><tr><td>Prediction execution time</td><td>▁</td></tr><tr><td>Training execution time</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▄▄▄▄▅▅▅▅▅▆▆▆▇▇▇██</td></tr><tr><td>mom_0</td><td>██████████▇▇▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▄▄▄▄▄▃▃▃▂▂▂▁▁</td></tr><tr><td>raw_loss</td><td>▂▁▁▁▁▁▁▁▁▁▁▆▂▁▆▁▁▁█▁▃▁▁▁▁▁▁▁▁▇▁▁▁▁▅▂▅▂▁▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>█▄▃▃▅▁▃▃▃▂▂▂▃▁▂▂▁▂▃▂▂▃▂▂▃▂▃▁▃▃▁▂▂▁▁▁▂▃▁▂</td></tr><tr><td>train_samples_per_sec</td><td>██▇█▇█▇███▁██▇▇▇▇▇▇█▇▇▇▇▇▇▇▇▇▆█▁▇▇▇▇▇▇▇▆</td></tr><tr><td>valid_loss</td><td>██▅▆▃▁▅▂</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>0.894</td></tr><tr><td>Average precision</td><td>0.655</td></tr><tr><td>Card Precision@100</td><td>0.297</td></tr><tr><td>F1 score</td><td>0.652</td></tr><tr><td>Prediction execution time</td><td>4.217</td></tr><tr><td>Training execution time</td><td>224.28854</td></tr><tr><td>epoch</td><td>8</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.00055</td></tr><tr><td>mom_0</td><td>0.9268</td></tr><tr><td>raw_loss</td><td>0.27263</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.02328</td></tr><tr><td>train_samples_per_sec</td><td>509.61257</td></tr><tr><td>valid_loss</td><td>0.02052</td></tr><tr><td>wd_0</td><td>0.01</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vibrant-paper-576</strong>: <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/2x8pwu2e" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/2x8pwu2e</a><br/>Synced 5 W&B file(s), 0 media file(s), 1 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230124_175901-2x8pwu2e\logs</code>

# %% [markdown]
# ### Sweeps

# %%
start_date_training = datetime.datetime.strptime("2018-07-25", "%Y-%m-%d")
delta_train=7
delta_delay=7
delta_test=7
delta_valid = delta_test

n_folds=4

start_date_training_for_valid = start_date_training+datetime.timedelta(days=-(delta_delay+delta_valid))
start_date_training_for_test = start_date_training+datetime.timedelta(days=(n_folds-1)*delta_test)
delta_assessment = delta_valid

SEED = 42
seed_everything(SEED)

prequential_split = []
        
for fold in range(n_folds):
    start_date_training_fold = start_date_training-datetime.timedelta(days=fold*delta_assessment)
    
    (train_df, test_df)=get_train_test_set(transactions_df,
                                            start_date_training=start_date_training_fold,
                                            delta_train=delta_train,delta_delay=delta_delay,delta_test=delta_assessment)
    
    prequential_split.append((train_df, test_df))

SEQ_LEN = 5
if torch.cuda.is_available():
    DEVICE = "cuda" 
else:
    DEVICE = "cpu"
print("Selected device is",DEVICE)
# Out:
# Selected device is cuda

# %%
sweep_config = {
                'method': 'random', 
                'metric': {
                    'goal': 'minimize',
                    'name': 'val_loss'
                    },
                'parameters': {
                    'one_cycle_policy' : {
                        'value' : True
                    },
                    'batch_size': {
                        'values' : [64, 128, 256]
                    },
                    'max_epochs': {
                        'values': [2, 4, 6, 8, 10, 12]
                    },
                    'num_workers': {
                        'value' : 0
                    },
                    'seed': {
                        'value' : SEED
                    },
                    'layers': {
                        'value': [8*128, 5 * 128 * 256 + 2 * 256  *128]
                    },
                    'few_shot': {
                        'value': False
                    }
                }
 }

# %%
sweep_id = wandb.sweep(sweep_config, project="mgr-anomaly-tsxai-project")
# Out:
# Create sweep with ID: m208kzbr
# Sweep URL: https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr

# %%
def train(config=None):
    with wandb.init(project="mgr-anomaly-tsxai-project", config=config, tags=['omniscalecnn', 'tsai', 'imbalance-not-considered', 'sweeps']):
        config = wandb.config
        training_execution_times = []
        prediction_execution_times = []
        aucs = []
        average_precisions = []
        f1_scores = []
        card_precisions = []
        for i in range(n_folds):
            train_df = prequential_split[i][0]
            valid_df = prequential_split[i][1]
            (train_df, valid_df)=scaleData(train_df, valid_df,input_features)
            x_train, y_train = prepare_sequenced_X_y(train_df, SEQ_LEN, input_features, output_feature)
            x_valid, y_valid = prepare_sequenced_X_y(valid_df, SEQ_LEN, input_features, output_feature)
            X, y, tsai_splits = tsai.all.combine_split_data([x_train.numpy(), x_valid.numpy()], [y_train.numpy(), y_valid.numpy()])
            dsets = tsai.all.TSDatasets(X, y, splits=tsai_splits, inplace=True)
            dls = tsai.all.TSDataLoaders.from_dsets(dsets.train, dsets.valid, bs=config.batch_size, num_workers=config.num_workers, device=DEVICE, drop_last=False, batch_tfms=tsai.all.TSStandardize(by_var=True))
            
            model = tsai.all.OmniScaleCNN(
                c_in=dls.vars, 
                c_out=dls.c,
                seq_len=SEQ_LEN,
                layers=config.layers,
                few_shot=config.few_shot
                )
            
            criterion = tsai.all.BCEWithLogitsLossFlat()
            learn = tsai.all.ts_learner(
                dls,
                model,
                loss_func=criterion,
                opt_func=tsai.all.Adam,
                device=DEVICE,
                metrics=[],
                model_dir='OmniScaleCNN',
                cbs=[
                    WandbCallback(
                        log=None,
                        log_model=False,
                        seed=config.seed)])

            valley = learn.lr_find().valley

            start_time=time.time()
            learn.fit_one_cycle(config.max_epochs, valley)
            training_execution_times.append(time.time()-start_time)

            start_time=time.time()
            valid_predictions_logits = get_predictions_sequential(learn.model.cuda(), dls.valid)
            prediction_execution_times.append(time.time()-start_time)
            predictions_df = valid_df
            predictions_df['predictions'] = torch.nn.Sigmoid()(torch.FloatTensor(valid_predictions_logits)).numpy()
                
            performance_df = performance_assessment_f1_included(predictions_df, top_k_list=[100])
            aucs.append(performance_df.loc[0,'AUC ROC'])
            average_precisions.append(performance_df.loc[0,'Average precision'])
            f1_scores.append(performance_df.loc[0,'F1 score'])
            card_precisions.append(performance_df.loc[0,'Card Precision@100'])

        wandb.log({'Training execution time': np.sum(training_execution_times) / n_folds})
        wandb.log({'Prediction execution time': np.sum(prediction_execution_times) / n_folds})
        wandb.log({'AUC ROC': np.sum(aucs) / n_folds})
        wandb.log({'Average precision': np.sum(average_precisions) / n_folds})
        wandb.log({'F1 score': np.sum(f1_scores) / n_folds})
        wandb.log({'Card Precision@100': np.sum(card_precisions) / n_folds})

# %%
# only 18 possible combinations of hyperparameters
wandb.agent(sweep_id, train, count=18)
# Out:
# wandb: Agent Starting Run: ao24dq3l with config:
# wandb: 	batch_size: 256
# wandb: 	few_shot: False
# wandb: 	layers: [1024, 229376]
# wandb: 	max_epochs: 10
# wandb: 	num_workers: 0
# wandb: 	one_cycle_policy: True
# wandb: 	seed: 42
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>d:\repos\mgr-anomaly-ts-xai\tsai\tsai-sweeps-models_testing\wandb\run-20230810_005039-ao24dq3l</code>
# Syncing run <strong><a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/ao24dq3l" target="_blank">logical-sweep-1</a></strong> to <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.034183</td>
#       <td>0.025859</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.029882</td>
#       <td>0.023612</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.023846</td>
#       <td>0.020716</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.019625</td>
#       <td>0.020597</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.020313</td>
#       <td>0.020835</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.015579</td>
#       <td>0.021010</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.016008</td>
#       <td>0.019981</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.013187</td>
#       <td>0.020185</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.012828</td>
#       <td>0.019644</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.009748</td>
#       <td>0.019772</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.031458</td>
#       <td>0.026924</td>
#       <td>00:13</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.023295</td>
#       <td>0.024889</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.021395</td>
#       <td>0.021660</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.019351</td>
#       <td>0.020585</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.016874</td>
#       <td>0.022473</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.014498</td>
#       <td>0.021757</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.015420</td>
#       <td>0.019459</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.014633</td>
#       <td>0.019939</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.012144</td>
#       <td>0.020127</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.009630</td>
#       <td>0.020146</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.037284</td>
#       <td>0.039027</td>
#       <td>00:14</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.028446</td>
#       <td>0.022537</td>
#       <td>00:15</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.023659</td>
#       <td>0.019640</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.023812</td>
#       <td>0.022333</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021857</td>
#       <td>0.022165</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.019388</td>
#       <td>0.018229</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.015124</td>
#       <td>0.019221</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.013568</td>
#       <td>0.018314</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.013039</td>
#       <td>0.018390</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.012815</td>
#       <td>0.018524</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.036730</td>
#       <td>0.025978</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.025219</td>
#       <td>0.020173</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.022991</td>
#       <td>0.023149</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021594</td>
#       <td>0.017387</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019356</td>
#       <td>0.016799</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.019075</td>
#       <td>0.017076</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.014785</td>
#       <td>0.017297</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.013989</td>
#       <td>0.017150</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.012815</td>
#       <td>0.016909</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.013231</td>
#       <td>0.017131</td>
#       <td>00:16</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>▁</td></tr><tr><td>Average precision</td><td>▁</td></tr><tr><td>Card Precision@100</td><td>▁</td></tr><tr><td>F1 score</td><td>▁</td></tr><tr><td>Prediction execution time</td><td>▁</td></tr><tr><td>Training execution time</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▂▅██▇▆▄▃▂▁▁▄▇▇▆▅▄▃▂▁▂▅▇▇▆▅▄▃▂▁▁▃▅▅▅▄▃▂▂▁</td></tr><tr><td>mom_0</td><td>▇▄▁▁▂▃▅▆▇██▅▁▁▂▃▄▆▇█▇▄▁▁▂▃▅▆▇██▅▁▁▂▃▄▆▇█</td></tr><tr><td>raw_loss</td><td>▅▅▂▆▂▁▁▁▁▄▃▂▃▆▅▁▃▂▂▂▅▂▇▃▃▃▂▃▁▁█▃▁▂▁▂▃▁▂▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▅▂▂▂▁▂▁▁▁▁█▃▂▂▂▂▁▁▁▁▅▃▂▂▂▂▂▁▁▁█▃▂▂▂▂▂▁▁▁</td></tr><tr><td>train_samples_per_sec</td><td>▆█▅█▇▇▇▆▇▆▆▄▅▅▅▄▅▄▃▄▆▄▄▄▄▄▁▄▄▄▄▄▄▄▃▄▄▄▁▄</td></tr><tr><td>valid_loss</td><td>▄▃▂▂▂▂▂▂▂▂▄▄▃▂▃▃▂▂▂▂█▃▂▃▃▁▂▁▂▂▄▂▃▁▁▁▁▁▁▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>0.8765</td></tr><tr><td>Average precision</td><td>0.6635</td></tr><tr><td>Card Precision@100</td><td>0.28775</td></tr><tr><td>F1 score</td><td>0.69375</td></tr><tr><td>Prediction execution time</td><td>3.506</td></tr><tr><td>Training execution time</td><td>150.85062</td></tr><tr><td>epoch</td><td>40</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>raw_loss</td><td>0.04471</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.01323</td></tr><tr><td>train_samples_per_sec</td><td>4275.46379</td></tr><tr><td>valid_loss</td><td>0.01713</td></tr><tr><td>wd_0</td><td>0.01</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">logical-sweep-1</strong>: <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/ao24dq3l" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/ao24dq3l</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230810_005039-ao24dq3l\logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: bht7xwgj with config:
# wandb: 	batch_size: 64
# wandb: 	few_shot: False
# wandb: 	layers: [1024, 229376]
# wandb: 	max_epochs: 2
# wandb: 	num_workers: 0
# wandb: 	one_cycle_policy: True
# wandb: 	seed: 42
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016933333333327028, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>d:\repos\mgr-anomaly-ts-xai\tsai\tsai-sweeps-models_testing\wandb\run-20230810_010200-bht7xwgj</code>
# Syncing run <strong><a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/bht7xwgj" target="_blank">sparkling-sweep-2</a></strong> to <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.017754</td>
#       <td>0.024811</td>
#       <td>00:36</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.019789</td>
#       <td>0.018665</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.030552</td>
#       <td>0.025828</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.016266</td>
#       <td>0.020211</td>
#       <td>00:43</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.028555</td>
#       <td>0.020867</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.018856</td>
#       <td>0.018651</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.027772</td>
#       <td>0.019458</td>
#       <td>00:42</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.015187</td>
#       <td>0.016716</td>
#       <td>00:42</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>▁</td></tr><tr><td>Average precision</td><td>▁</td></tr><tr><td>Card Precision@100</td><td>▁</td></tr><tr><td>F1 score</td><td>▁</td></tr><tr><td>Prediction execution time</td><td>▁</td></tr><tr><td>Training execution time</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▁▂▃▃▃▂▂▂▁▁▂▆███▆▄▃▂▁▁▂▃▃▃▂▂▁▁▁▁▂▃▃▂▂▂▁▁▁</td></tr><tr><td>mom_0</td><td>▇▅▁▁▂▃▄▆▇██▃▁▁▂▃▅▆▇██▄▁▁▂▄▅▆▇█▇▅▁▁▂▃▅▆▇█</td></tr><tr><td>raw_loss</td><td>▁▂▁▃▅▁▁▄▄▁▁▁▆▁▅▁▁▁▁▁█▂▁▁▁▁▁▁▁▁▂▁▄▁▁▁▁▁▁▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▂▂▁▁▁▁▁▁▁▁▂▂▁▁▁▁▁▁▁▁█▂▁▁▁▁▁▁▁▁▃▂▁▁▁▁▁▁▁▁</td></tr><tr><td>train_samples_per_sec</td><td>█▅▅▇▅▄▃▄▄▄▄▅▄▂▄▁▅▄▄▄▇▃▄▄▄▄▄▄▄▄▄▄▃▃▄▂▄▄▁▃</td></tr><tr><td>valid_loss</td><td>▇▂█▄▄▂▃▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>0.87725</td></tr><tr><td>Average precision</td><td>0.63625</td></tr><tr><td>Card Precision@100</td><td>0.289</td></tr><tr><td>F1 score</td><td>0.661</td></tr><tr><td>Prediction execution time</td><td>7.442</td></tr><tr><td>Training execution time</td><td>82.9595</td></tr><tr><td>epoch</td><td>8</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>raw_loss</td><td>0.00168</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.01519</td></tr><tr><td>train_samples_per_sec</td><td>567.05415</td></tr><tr><td>valid_loss</td><td>0.01672</td></tr><tr><td>wd_0</td><td>0.01</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sparkling-sweep-2</strong>: <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/bht7xwgj" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/bht7xwgj</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230810_010200-bht7xwgj\logs</code>
# wandb: Agent Starting Run: mijikyew with config:
# wandb: 	batch_size: 128
# wandb: 	few_shot: False
# wandb: 	layers: [1024, 229376]
# wandb: 	max_epochs: 4
# wandb: 	num_workers: 0
# wandb: 	one_cycle_policy: True
# wandb: 	seed: 42
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016666666666666666, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>d:\repos\mgr-anomaly-ts-xai\tsai\tsai-sweeps-models_testing\wandb\run-20230810_010848-mijikyew</code>
# Syncing run <strong><a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/mijikyew" target="_blank">rich-sweep-3</a></strong> to <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.028125</td>
#       <td>0.024448</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.020422</td>
#       <td>0.020196</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.019412</td>
#       <td>0.018938</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.016478</td>
#       <td>0.018251</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.029794</td>
#       <td>0.033259</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.021234</td>
#       <td>0.021958</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.017194</td>
#       <td>0.020451</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.013689</td>
#       <td>0.019189</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.036427</td>
#       <td>0.023122</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.029828</td>
#       <td>0.022266</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.019223</td>
#       <td>0.018783</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.018501</td>
#       <td>0.018623</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.027458</td>
#       <td>0.029956</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.019258</td>
#       <td>0.023744</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.014375</td>
#       <td>0.017052</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.015054</td>
#       <td>0.016276</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>▁</td></tr><tr><td>Average precision</td><td>▁</td></tr><tr><td>Card Precision@100</td><td>▁</td></tr><tr><td>F1 score</td><td>▁</td></tr><tr><td>Prediction execution time</td><td>▁</td></tr><tr><td>Training execution time</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▂▃▅▅▅▄▃▂▁▁▁▄▅▅▅▄▃▂▁▁▁▂▃▃▂▂▂▁▁▁▂▄██▇▆▄▃▂▁</td></tr><tr><td>mom_0</td><td>▇▅▁▁▂▃▄▆▇██▃▁▁▂▃▅▆▇██▄▁▁▂▄▅▆▇█▇▅▁▁▂▃▅▆▇█</td></tr><tr><td>raw_loss</td><td>▃▂▁▁▁▁▁▁▃▁▂▁▁▁▃▁▂▁▆▁█▂▁▃▁▁▃▁▁▁▁▃▁▂▁▁▄▁▁▂</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▂▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁█▂▁▁▁▁▁▁▁▁▂▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_samples_per_sec</td><td>█▇▇▇▆▅▁▄▅▄▇▅▄▅▄▂▄▄▄▅▄▄▅▄▄▄▄▄▄▄▄▅▅▅▄▅▄▄▄▃</td></tr><tr><td>valid_loss</td><td>▄▃▂▂█▃▃▂▄▃▂▂▇▄▁▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>0.8815</td></tr><tr><td>Average precision</td><td>0.65475</td></tr><tr><td>Card Precision@100</td><td>0.2895</td></tr><tr><td>F1 score</td><td>0.67375</td></tr><tr><td>Prediction execution time</td><td>4.9845</td></tr><tr><td>Training execution time</td><td>95.3615</td></tr><tr><td>epoch</td><td>16</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>raw_loss</td><td>0.0021</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.01505</td></tr><tr><td>train_samples_per_sec</td><td>551.27703</td></tr><tr><td>valid_loss</td><td>0.01628</td></tr><tr><td>wd_0</td><td>0.01</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">rich-sweep-3</strong>: <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/mijikyew" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/mijikyew</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230810_010848-mijikyew\logs</code>
# wandb: Agent Starting Run: 3lxgziew with config:
# wandb: 	batch_size: 128
# wandb: 	few_shot: False
# wandb: 	layers: [1024, 229376]
# wandb: 	max_epochs: 8
# wandb: 	num_workers: 0
# wandb: 	one_cycle_policy: True
# wandb: 	seed: 42
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016916666666656966, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>d:\repos\mgr-anomaly-ts-xai\tsai\tsai-sweeps-models_testing\wandb\run-20230810_011625-3lxgziew</code>
# Syncing run <strong><a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/3lxgziew" target="_blank">youthful-sweep-4</a></strong> to <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.027640</td>
#       <td>0.028304</td>
#       <td>00:20</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.028670</td>
#       <td>0.023839</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.022410</td>
#       <td>0.021563</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.020210</td>
#       <td>0.019308</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.018418</td>
#       <td>0.018384</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.014038</td>
#       <td>0.019611</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.013872</td>
#       <td>0.018951</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012001</td>
#       <td>0.019064</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.022326</td>
#       <td>0.036001</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.021442</td>
#       <td>0.024656</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.020628</td>
#       <td>0.023022</td>
#       <td>00:24</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021037</td>
#       <td>0.020765</td>
#       <td>00:25</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.016743</td>
#       <td>0.019842</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.016177</td>
#       <td>0.019539</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.011054</td>
#       <td>0.019452</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.013382</td>
#       <td>0.019630</td>
#       <td>00:24</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.032594</td>
#       <td>0.032080</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.029081</td>
#       <td>0.021779</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.032835</td>
#       <td>0.019710</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.025521</td>
#       <td>0.018039</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019516</td>
#       <td>0.017518</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.017315</td>
#       <td>0.017537</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.018007</td>
#       <td>0.017797</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012948</td>
#       <td>0.017407</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.026260</td>
#       <td>0.021466</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.021872</td>
#       <td>0.018421</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.024171</td>
#       <td>0.018729</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022015</td>
#       <td>0.017717</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.021200</td>
#       <td>0.015937</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.014472</td>
#       <td>0.015992</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.023321</td>
#       <td>0.015964</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.012821</td>
#       <td>0.015911</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# ...
#       <td>00:40</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.017275</td>
#       <td>0.015636</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.018223</td>
#       <td>0.016108</td>
#       <td>00:41</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.016865</td>
#       <td>0.016007</td>
#       <td>00:41</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>▁</td></tr><tr><td>Average precision</td><td>▁</td></tr><tr><td>Card Precision@100</td><td>▁</td></tr><tr><td>F1 score</td><td>▁</td></tr><tr><td>Prediction execution time</td><td>▁</td></tr><tr><td>Training execution time</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▁▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▂▃▆▆▅▄▄▂▁▁▁▂▂▂▂▂▁▁▁▁▁▄▇▇▆▅▄▂▂▁▂▄██▇▆▄▃▂▁</td></tr><tr><td>mom_0</td><td>▇▅▁▁▂▃▄▆▇██▃▁▁▂▃▅▆▇██▄▁▁▂▄▅▆▇█▇▅▁▁▂▃▅▆▇█</td></tr><tr><td>raw_loss</td><td>▁▅▁▁▄▁▁▁▁▁▂▁▁▃▁▁▁▆▁▁▃▁▁▃▁▁▁▁▁▁▃▁▃█▂▁▅▁▁▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▄▃▃▃▃▃▂▂▂▂█▅▄▄▄▃▃▃▂▂▆▃▄▃▃▃▂▂▁▂▄▃▃▄▃▃▃▂▁▁</td></tr><tr><td>train_samples_per_sec</td><td>█▇▆▅▆▆▆▆▆▅▆▆▆▆▆▆▆▅▆▆▇▆▆▇▅▅▆▆▇▅▁▆▆▆▆▆▆▆▅▇</td></tr><tr><td>valid_loss</td><td>▃▂▂▂▂▂▂▂█▃▃▄▄▃▇▅▃▃▂▂▂▁▁▁▂▂▂▁▁▁▁▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>0.852</td></tr><tr><td>Average precision</td><td>0.60725</td></tr><tr><td>Card Precision@100</td><td>0.26</td></tr><tr><td>F1 score</td><td>0.58975</td></tr><tr><td>Prediction execution time</td><td>6.92075</td></tr><tr><td>Training execution time</td><td>327.161</td></tr><tr><td>epoch</td><td>32</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>raw_loss</td><td>0.00114</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.01687</td></tr><tr><td>train_samples_per_sec</td><td>595.08578</td></tr><tr><td>valid_loss</td><td>0.01601</td></tr><tr><td>wd_0</td><td>0.01</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">dashing-sweep-17</strong>: <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/ybum00dp" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/ybum00dp</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230810_044925-ybum00dp\logs</code>
# wandb: Agent Starting Run: cjjednhb with config:
# wandb: 	batch_size: 128
# wandb: 	few_shot: False
# wandb: 	layers: [1024, 229376]
# wandb: 	max_epochs: 6
# wandb: 	num_workers: 0
# wandb: 	one_cycle_policy: True
# wandb: 	seed: 42
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# VBox(children=(Label(value='Waiting for wandb.init()...\r'), FloatProgress(value=0.016933333333327028, max=1.0…
# wandb version 0.15.8 is available!  To upgrade, please run:
#  $ pip install wandb --upgrade
# Tracking run with wandb version 0.13.6
# Run data is saved locally in <code>d:\repos\mgr-anomaly-ts-xai\tsai\tsai-sweeps-models_testing\wandb\run-20230810_051232-cjjednhb</code>
# Syncing run <strong><a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/cjjednhb" target="_blank">robust-sweep-18</a></strong> to <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/sweeps/m208kzbr</a>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.029634</td>
#       <td>0.022234</td>
#       <td>00:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.026207</td>
#       <td>0.020302</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.018935</td>
#       <td>0.019809</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.022062</td>
#       <td>0.020846</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.012442</td>
#       <td>0.018765</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.015297</td>
#       <td>0.018523</td>
#       <td>00:23</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.030598</td>
#       <td>0.027071</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.026300</td>
#       <td>0.022908</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.021703</td>
#       <td>0.020949</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.014292</td>
#       <td>0.019855</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.013234</td>
#       <td>0.019570</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.015809</td>
#       <td>0.019933</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.031045</td>
#       <td>0.023449</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.023060</td>
#       <td>0.021213</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.025130</td>
#       <td>0.019676</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.024234</td>
#       <td>0.017810</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.019412</td>
#       <td>0.017563</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.017896</td>
#       <td>0.017630</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# WandbCallback was not able to prepare a DataLoader for logging prediction samples -> 'NoneType' object is not iterable
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.025638</td>
#       <td>0.020065</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.026104</td>
#       <td>0.028601</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.020957</td>
#       <td>0.016835</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.021548</td>
#       <td>0.016983</td>
#       <td>00:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.017818</td>
#       <td>0.016424</td>
#       <td>00:23</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.016054</td>
#       <td>0.015823</td>
#       <td>00:22</td>
#     </tr>
#   </tbody>
# </table>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>▁</td></tr><tr><td>Average precision</td><td>▁</td></tr><tr><td>Card Precision@100</td><td>▁</td></tr><tr><td>F1 score</td><td>▁</td></tr><tr><td>Prediction execution time</td><td>▁</td></tr><tr><td>Training execution time</td><td>▁</td></tr><tr><td>epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇███</td></tr><tr><td>eps_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>lr_0</td><td>▁▃▅▆▅▄▄▂▂▁▁▄▆▆▅▄▃▂▂▁▁▄▆▆▅▄▃▂▁▁▂▇██▇▅▄▂▂▁</td></tr><tr><td>mom_0</td><td>█▅▂▁▂▃▄▆▇██▄▁▁▂▃▅▆▇██▃▁▁▂▄▅▆▇█▇▂▁▁▂▄▅▇▇█</td></tr><tr><td>raw_loss</td><td>▃▁▁▁▁▁▁▂▁▁▄▂▂▂▁▁▁▁▄▄▃▁█▁▇▄▁▁▁▃▄▂▁▂▃▄▁▃▅▁</td></tr><tr><td>sqr_mom_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_loss</td><td>▃▂▂▂▂▁▁▂▁▁█▂▂▂▁▁▁▁▁▁▃▂▂▁▂▁▁▁▁▁▃▂▂▂▂▂▁▁▁▁</td></tr><tr><td>train_samples_per_sec</td><td>██▃▄▂▁▃▃▃▃▂▄▃▃▂▂▂▃▄▄▃▃▃▂▃▃▃▃▃▃▂▃▃▃▃▃▃▂▃▂</td></tr><tr><td>valid_loss</td><td>▅▃▃▄▃▂▇▅▄▃▃▃▅▄▃▂▂▂▃█▂▂▁▁</td></tr><tr><td>wd_0</td><td>▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>AUC ROC</td><td>0.87975</td></tr><tr><td>Average precision</td><td>0.671</td></tr><tr><td>Card Precision@100</td><td>0.28625</td></tr><tr><td>F1 score</td><td>0.68775</td></tr><tr><td>Prediction execution time</td><td>4.55525</td></tr><tr><td>Training execution time</td><td>135.8365</td></tr><tr><td>epoch</td><td>24</td></tr><tr><td>eps_0</td><td>1e-05</td></tr><tr><td>lr_0</td><td>0.0</td></tr><tr><td>mom_0</td><td>0.95</td></tr><tr><td>raw_loss</td><td>0.00315</td></tr><tr><td>sqr_mom_0</td><td>0.99</td></tr><tr><td>train_loss</td><td>0.01605</td></tr><tr><td>train_samples_per_sec</td><td>570.31401</td></tr><tr><td>valid_loss</td><td>0.01582</td></tr><tr><td>wd_0</td><td>0.01</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">robust-sweep-18</strong>: <a href="https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/cjjednhb" target="_blank">https://wandb.ai/mgr-anomaly-tsxai/mgr-anomaly-tsxai-project/runs/cjjednhb</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>.\wandb\run-20230810_051232-cjjednhb\logs</code>
